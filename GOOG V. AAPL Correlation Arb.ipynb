# %% [markdown]
# ##Google Vs. Apple Correlation Arbitrage Trading Algorithm | By Andrew Conti
# This notebook contains a algorithm designed to profit off of the correlation between Apple's and Google's common stock in December 2012 to May 2012.
#
# This notebook and the data used in this example is located at [http://github.com/agconti/AGCTrading](http://github.com/agconti/AGCTrading).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
plt.figsize(18,6)

from zipline.algorithm import TradingAlgorithm
from zipline.transforms import MovingAverage, batch_transform
from zipline.utils.factory import load_from_yahoo

# %%
# Uncomment the line below to get the data for yourself, but it is already included in the above mentioned repository
#data = load_from_yahoo(stocks=['AAPL', 'GOOG'],start=datetime.datetime(2012,11,1), end=datetime.datetime(2013,5,8)); data.save('goog_aapl_tests.dat')
data = pd.load('goog_aapl_tests.dat')

# %% [markdown]
# ###Here is the phenomenon:
#
# There clearly seems to be a divergence in the two closing prices after December 2012. If you to extend this chart backwards to early 2012 you would see the stocks were moving relatively together.

# %%
fig = plt.figure(figsize(12,6))

#data.SPX.plot(label='S&P Benchmark')
data.GOOG.plot()
data.AAPL.plot()

legend(loc='best')
plt.title("Apple & Google Adj Closing Prices")

# %% [markdown]
# ###The Trading Algorithm:
#
# Here is the most basic version of our algorithm and will be refined later in the notebook. It works by comparing the prices between Google and Apple,( `self.pricea` for Apple and `self.priceg` for Google), and then buys / sells stock if the correlation of the stocks in the last 5 days is greater than (0.90). To determine whether to buy or sell Google stock, it checks the movement of Apple's stock. If Apple's stock went down yesterday relative to today, it buys Google;  if apple's stock went up it sells Google. It does this by evaluating price variables with a 1 period lagged price variable. At the daily level that period is 1 day; at the minute bar level that period is 1 minuet of tick data.
#
# Heres the code:
#
#         if priceg < self.priceglag and corr > self.corr_tolerance:
# 			self.order('AAPL',-100)
# 			self.sell_orders.append((data.AAPL.datetime, pval))
# 			print "{dt}: Selling 100 AAPL shares.".format(dt = data.AAPL.datetime)
# 		elif priceg > self.priceglag and corr > self.corr_tolerance:
# 			self.order('AAPL',100)
# 			self.buy_orders.append((data.AAPL.datetime, pval))
# 			print "{dt}: Buying 100 AAPL shares.".format(dt = data.AAPL.datetime)
#
# The stock does the oppiste for trading Apple's stock. In this way, the pricing algorithm checks the correlations to see if in fact the stocks have been following each other within expected tolerances and then trades each stock by the other's divergence. The algorithm to do so is shown below:

# %%
class GOOG_AAPL_COR(TradingAlgorithm): # inherit from TradingAlgorithm
    """
    Google Apple Correlation algorithm.

    An algorithm designed to exploit the correlation in the movement of Apple's and 
    Google's common stock. 
    """
    def initialize(self):
        self.AUM = 1000000
        self.pricea = 0
        self.priceg = 0
        self.window_length = 5 
        self.corr_tolerance = 0.9
        self.max_notional = self.AUM + 0.1
        self.min_notional = self.AUM * (-1) 
        self.pricealag = 0
        self.priceglag = 0
        self.buy_orders = []
        self.sell_orders = [] 
        self.corr_values_aapl = []
        self.corr_values_goog = []

    def handle_data(self, data):

        self.pricea = data.AAPL.price
        self.priceg = data.GOOG.price   
        
        corr, pval = self.correlation(data, self.pricea, self.priceg)
        print 'Pearson Correlation: ' + str(corr)

        #notional = self.portfolio.positions[data.AAPL].amount * pricea
        #notional = notional + self.portfolio.positions[data.GOOG].amount * priceg 
        

        # need to include and optimization for # of shares
        if self.priceg < self.priceglag and corr > self.corr_tolerance:
            self.order('AAPL',-100)
            self.sell_orders.append((data.AAPL.datetime, pval))
            print "{dt}: Selling 100 AAPL shares.".format(dt = data.AAPL.datetime)
        elif self.priceg > self.priceglag and corr > self.corr_tolerance:
            self.order('AAPL',100)
            self.buy_orders.append((data.AAPL.datetime, pval))
            print "{dt}: Buying 100 AAPL shares.".format(dt = data.AAPL.datetime)

        if self.pricea < self.pricealag and  corr > self.corr_tolerance:
            self.order('GOOG',-100)
            self.sell_orders.append((data.GOOG.datetime, pval))
            print "{dt}: Selling 100 GOOG shares.".format(dt = data.GOOG.datetime)
        elif self.pricea > self.pricealag and corr > self.corr_tolerance:
            self.order('GOOG',100)
            self.buy_orders.append((data.GOOG.datetime, pval))  
            print "{dt}: Buying 100 GOOG shares.".format(dt = data.GOOG.datetime)

        # lag price variables 
        self.pricealag = data.AAPL.price
        self.priceglag = data.GOOG.price

    def correlation(self, data, pricea, priceg):
        self.corr_values_aapl.append(pricea)
        self.corr_values_goog.append(priceg)
        corr = pearsonr(self.corr_values_aapl[-self.window_length:], self.corr_values_goog[-self.window_length:]) # [0] only get the correltion
        return corr

# %% [markdown]
# ###Lets simulate our algorithm on daily returns:

# %%
GOOG_AAPL_COR = GOOG_AAPL_COR()
results_GOOG_AAPL_COR = GOOG_AAPL_COR.run(data)
# Out:
# Pearson Correlation: nan
# Pearson Correlation: -1.0
# Pearson Correlation: 0.059824040231
# Pearson Correlation: 0.174659180436
# Pearson Correlation: 0.824233785309
# Pearson Correlation: 0.952297709192
# 2012-11-08 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-08 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.991554650251
# 2012-11-09 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-09 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.929368022202
# 2012-11-12 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-12 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.757576476824
# Pearson Correlation: 0.845836369332
# Pearson Correlation: 0.904363385855
# 2012-11-15 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-15 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.919167495476
# 2012-11-16 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-16 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.98644535697
# 2012-11-19 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-19 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.988017374005
# 2012-11-20 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-20 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.98614541901
# 2012-11-21 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-21 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.956502301266
# 2012-11-23 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-23 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: -0.850795924042
# Pearson Correlation: -0.388234458157
# Pearson Correlation: 0.132856328942
# Pearson Correlation: 0.244364901771
# Pearson Correlation: -0.233575324747
# Pearson Correlation: 0.394085687777
# Pearson Correlation: 0.281478815016
# Pearson Correlation: 0.738307236796
# Pearson Correlation: 0.840028399437
# Pearson Correlation: 0.87515944915
# Pearson Correlation: 0.793381038641
# Pearson Correlation: 0.699662917774
# Pearson Correlation: 0.61994502866
# Pearson Correlation: 0.269620004501
# Pearson Correlation: -0.279590717582
# Pearson Correlation: -0.546140037064
# Pearson Correlation: -0.0881216339673
# Pearson Correlation: 0.403905418053
# Pearson Correlation: 0.755250505131
# Pearson Correlation: 0.339476408109
# Pearson Correlation: 0.549057229948
# Pearson Correlation: 0.739033938857
# Pearson Correlation: 0.744796824599
# Pearson Correlation: 0.821945371289
# Pearson Correlation: 0.466884246454
# Pearson Correlation: 0.876920310513
# Pearson Correlation: 0.927515534537
# 2013-01-03 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-01-03 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.494477226709
# Pearson Correlation: -0.387391976151
# Pearson Correlation: -0.927721502534
# Pearson Correlation: -0.909803583801
# Pearson Correlation: -0.233228339811
# Pearson Correlation: -0.446151532632
# Pearson Correlation: 0.806202475541
# Pearson Correlation: 0.907783047386
# 2013-01-15 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-01-15 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.696926220586
# Pearson Correlation: 0.442689440196
# Pearson Correlation: -0.496565907528
# Pearson Correlation: -0.717758128217
# Pearson Correlation: 0.91836915185
# 2013-01-23 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-01-23 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: -0.601692961309
# Pearson Correlation: -0.703340810332
# Pearson Correlation: -0.708631151794
# Pearson Correlation: -0.942863822082
# Pearson Correlation: 0.105071788809
# Pearson Correlation: 0.267677939369
# Pearson Correlation: -0.0734603761372
# Pearson Correlation: -0.199311330537
# Pearson Correlation: 0.0510478602377
# Pearson Correlation: 0.353566175356
# Pearson Correlation: 0.693378247595
# Pearson Correlation: 0.952514956078
# 2013-02-08 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-02-08 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.922284099348
# 2013-02-11 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-02-11 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.855718558992
# Pearson Correlation: 0.442512222602
# Pearson Correlation: -0.15909805662
# Pearson Correlation: -0.660823444996
# Pearson Correlation: -0.873349113446
# Pearson Correlation: -0.373572157847
# Pearson Correlation: -0.101445899412
# Pearson Correlation: 0.398375188553
# Pearson Correlation: 0.935757136186
# 2013-02-25 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-02-25 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.488289511759
# Pearson Correlation: 0.236926672758
# Pearson Correlation: -0.134727207432
# Pearson Correlation: -0.800766068617
# Pearson Correlation: -0.966418239347
# Pearson Correlation: -0.612146269391
# Pearson Correlation: -0.523858670059
# Pearson Correlation: 0.128313159843
# Pearson Correlation: 0.856768169064
# Pearson Correlation: 0.37064308425
# Pearson Correlation: 0.694439233109
# Pearson Correlation: 0.848864875018
# Pearson Correlation: 0.583850851016
# Pearson Correlation: -0.382247521161
# Pearson Correlation: -0.986326278298
# Pearson Correlation: -0.982469497378
# Pearson Correlation: -0.916359799195
# Pearson Correlation: -0.69849547277
# Pearson Correlation: -0.483088392126
# Pearson Correlation: -0.769950032764
# Pearson Correlation: -0.692494102481
# Pearson Correlation: 0.534907310429
# Pearson Correlation: 0.973183362731
# 2013-03-28 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-03-28 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.726670249705
# Pearson Correlation: 0.143611794748
# Pearson Correlation: -0.465442720063
# Pearson Correlation: -0.395440571443
# Pearson Correlation: 0.888941897899
# Pearson Correlation: 0.799236827344
# Pearson Correlation: 0.759685868182
# Pearson Correlation: 0.457328874099
# Pearson Correlation: 0.780718813282
# Pearson Correlation: 0.863304390263
# Pearson Correlation: 0.724997330538
# Pearson Correlation: 0.623692113603
# Pearson Correlation: 0.744004178512
# Pearson Correlation: 0.894304567757
# Pearson Correlation: 0.204682970752
# Pearson Correlation: 0.203268615806
# Pearson Correlation: 0.408273152978
# Pearson Correlation: 0.696724629857
# Pearson Correlation: 0.829059086718
# [2013-05-28 02:49] INFO: Performance: Simulated 128 trading days out of 128.
# [2013-05-28 02:49] INFO: Performance: first open: 2012-11-01 13:30:00+00:00
# [2013-05-28 02:49] INFO: Performance: last close: 2013-05-07 20:00:00+00:00
# Pearson Correlation: -0.0460241057536
# Pearson Correlation: 0.405794075795
# Pearson Correlation: 0.707738144101
# Pearson Correlation: 0.859529936421
# Pearson Correlation: 0.964752298038
# 2013-05-02 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-05-02 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.838557400323
# Pearson Correlation: 0.985339456603
# 2013-05-06 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-05-06 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.987890482366
# 2013-05-07 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-05-07 00:00:00+00:00: Selling 100 GOOG shares.

# %% [markdown]
# ###Below is a graphical analysis of its performance:

# %%
plt.figure(figsize(18,10), dpi=800)
ax1 = plt.subplot(411)
data[['GOOG', 'AAPL']].plot(ax=ax1)
plt.ylabel('Price')
plt.setp(ax1.get_xticklabels(), visible=False)
plt.title("GOOG_AAPL_COR Results")
GOOG_AAPL_COR.buy_orders = np.asarray(GOOG_AAPL_COR.buy_orders)
GOOG_AAPL_COR.sell_orders = np.asarray(GOOG_AAPL_COR.sell_orders)

ax2 = plt.subplot(412, sharex=ax1)
plt.plot(GOOG_AAPL_COR.buy_orders[:,0], GOOG_AAPL_COR.buy_orders[:,1], color = 'g')
plt.plot(GOOG_AAPL_COR.sell_orders[:,0], GOOG_AAPL_COR.sell_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR.buy_orders[:,0], GOOG_AAPL_COR.buy_orders[:,1], '^', c='g', markersize=10, label='buy')
plt.plot(GOOG_AAPL_COR.sell_orders[:,0], GOOG_AAPL_COR.sell_orders[:,1], 'v', c='r', markersize=10, label='sell')
plt.ylabel('P-Value')
plt.grid(color = 'k')

plt.setp(ax2.get_xticklabels(), visible=False)
plt.legend()

ax3 = plt.subplot(413, sharex=ax1)
results_GOOG_AAPL_COR.portfolio_value.plot()
plt.ylabel('Portfolio Value')
plt.setp(ax3.get_xticklabels(), visible=False)
plt.legend()

ax4 = plt.subplot(414, sharex=ax1)
results_GOOG_AAPL_COR.portfolio_value.pct_change().plot()
plt.ylabel('Portfolio % Change')
plt.legend(loc='best')

# %%
results_GOOG_AAPL_COR.portfolio_value.describe() # show the summary statistics for our portfolio value
# Out:
# count       128.000000
# mean      82063.907695
# std       12848.221565
# min       59791.835000
# 25%       70769.587500
# 50%       78394.800000
# 75%       94918.471250
# max      100000.000000
# dtype: float64

# %%
results_GOOG_AAPL_COR.portfolio_value.pct_change().describe() # show the summary statistics for our returns
# Out:
# count    127.000000
# mean      -0.001590
# std        0.035399
# min       -0.220364
# 25%       -0.010637
# 50%       -0.001305
# 75%        0.014246
# max        0.089831
# dtype: float64

# %% [markdown]
# ###The Results:
#
# As you can see, the performance of the algorithm is poor. Its worst trading day lost the algorithm only 1.42 % but it experienced a drawdown of approximately 40% and finished our simulation with a 25% loss. The upside? It returned 3.95% in one day alone.

# %% [markdown]
# ###Lets do better.
#
# Lets clean the signal from the noise by adjusting Apple and Google's returns by the S&P returns. Through this process we are reducing the systematic noise in the movements of the two stock prices and getting closer to the actual signals of the two firm's movements. Below is a graphic representation of the process:

# %%
fig = plt.figure(figsize(18, 10), dpi=800)

ax1 = fig.add_subplot(211)
data.SPX.plot(label='S&P Benchmark')
data.GOOG.plot()
data.AAPL.plot()
plt.ylabel('Stock / Index Value')
legend(loc='best')
plt.setp(ax1.get_xticklabels(), visible=False)
plt.title("Adj Closing Prices")

ax2 = fig.add_subplot(212, sharex=ax1)
(data.SPX.pct_change() - data.SPX.pct_change()).plot(label='S&P Benchmark, flatlined')
(data.GOOG.pct_change() - data.SPX.pct_change()).plot(label='GOOG adj for var in S&P')
(data.AAPL.pct_change() - data.SPX.pct_change()).plot(label='AAPL adj for var in S&P')
plt.ylabel("Daily Return")
legend(loc='best')
plt.title("Adj Closing Prices adjusted for S&P movements")

# %% [markdown]
# ###Let's incorporate this idea into our algorithm:
#
# Here we will use the day's percent change instead of the adjusted closing value of the stock. Before we decide whether to buy or sell we will adjust the return by the return of the SPX in the same period. Then we will buy / sell the stock if they are moving within our correlation tolerance and if they are positive, (buy the stock), or negative, (sell the stock).
#
# The resulting trading algorithm is shown below:

# %%
class GOOG_AAPL_COR_V_SP500(TradingAlgorithm): # inherit from TradingAlgorithm
  """
  Google Apple Correlation algorithm adjusted for movements in the S&P500.

  An algorithm designed to exploit the correlation in the movement of Apple's and 
  Google's common stock. 
  """
  def initialize(self):
    self.AUM = 1000000
    self.pricea = 0
    self.priceg = 0
    self.pricespx = 0
    self.window_length = 5 
    self.corr_tolerance = 0.9
    self.max_notional = self.AUM + 0.1
    self.min_notional = self.AUM * (-1) 
    self.pricealag = 0
    self.priceglag = 0
    self.pricespxlag = 0
    self.buy_orders = []
    self.sell_orders = [] 
    self.corr_values_aapl = []
    self.corr_values_goog = []

  def handle_data(self, data):
    self.pricea = data.AAPL.price 
    self.priceg = data.GOOG.price  
    self.pricespx = data.SPX.price

    # find percent change and substract movements from SPX
    aapl_mov, goog_mov = self.spx_normalize(data, self.pricea, self.priceg, self.pricespx, self.pricealag, self.priceglag, self.pricespxlag)

    corr, pval = self.correlation(data, self.pricea, self.priceg)
    print 'Pearson Correlation: ' + str(corr)

    #notional = self.portfolio.positions[data.AAPL].amount * pricea
    #notional = notional + self.portfolio.positions[data.GOOG].amount * priceg 

    # need to include and optimization for # of shares
    if goog_mov < 0 and corr > self.corr_tolerance:
      self.order('AAPL',-100)
      self.sell_orders.append((data.AAPL.datetime, pval))
      print "{dt}: Selling 100 AAPL shares.".format(dt = data.AAPL.datetime)
    elif goog_mov > 0 and corr > self.corr_tolerance:
      self.order('AAPL',100)
      self.buy_orders.append((data.AAPL.datetime, pval))
      print "{dt}: Buying 100 AAPL shares.".format(dt = data.AAPL.datetime)

    if aapl_mov < 0 and  corr > self.corr_tolerance:
      self.order('GOOG',-100)
      self.sell_orders.append((data.GOOG.datetime, pval))
      print "{dt}: Selling 100 GOOG shares.".format(dt = data.GOOG.datetime)
    elif aapl_mov > 0 and corr > self.corr_tolerance:
      self.order('GOOG',100)
      self.buy_orders.append((data.GOOG.datetime, pval))  
      print "{dt}: Buying 100 GOOG shares.".format(dt = data.GOOG.datetime)

    # lag price variables 
    self.pricealag = data.AAPL.price
    self.priceglag = data.GOOG.price
    self.pricespxlag =  data.SPX.price

  def correlation(self, data, pricea, priceg):
    self.corr_values_aapl.append(self.pricea)
    self.corr_values_goog.append(self.priceg)
    corr = pearsonr(self.corr_values_aapl[-self.window_length:], self.corr_values_goog[-self.window_length:]) # [0] only get the correltion
    return corr

  def per_change(self, data, begin, end):
    percent_change = ((end - begin)/begin)
    return percent_change
    
  def spx_normalize(self, data, pricea, priceg, pricespx, pricealag, priceglag, pricespxlag):
    spx_change = self.per_change(data, pricespx, self.pricespxlag)
    aapl_change = (self.per_change(data, pricea, self.pricealag) - spx_change)
    goog_change = (self.per_change(data, priceg, self.priceglag) - spx_change)
    return (aapl_change, goog_change)

# %%
GOOG_AAPL_COR_V_SP500 = GOOG_AAPL_COR_V_SP500()
results_GOOG_AAPL_COR_V_SP500 = GOOG_AAPL_COR_V_SP500.run(data)
# Out:
# Pearson Correlation: nan
# Pearson Correlation: -1.0
# Pearson Correlation: 0.059824040231
# Pearson Correlation: 0.174659180436
# Pearson Correlation: 0.824233785309
# Pearson Correlation: 0.952297709192
# 2012-11-08 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-08 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.991554650251
# 2012-11-09 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-09 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.929368022202
# 2012-11-12 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-12 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.757576476824
# Pearson Correlation: 0.845836369332
# Pearson Correlation: 0.904363385855
# 2012-11-15 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-15 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.919167495476
# 2012-11-16 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-16 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.98644535697
# 2012-11-19 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-19 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.988017374005
# 2012-11-20 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-20 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.98614541901
# 2012-11-21 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-21 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.956502301266
# 2012-11-23 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-23 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: -0.850795924042
# Pearson Correlation: -0.388234458157
# Pearson Correlation: 0.132856328942
# Pearson Correlation: 0.244364901771
# Pearson Correlation: -0.233575324747
# Pearson Correlation: 0.394085687777
# Pearson Correlation: 0.281478815016
# Pearson Correlation: 0.738307236796
# Pearson Correlation: 0.840028399437
# Pearson Correlation: 0.87515944915
# Pearson Correlation: 0.793381038641
# Pearson Correlation: 0.699662917774
# Pearson Correlation: 0.61994502866
# Pearson Correlation: 0.269620004501
# Pearson Correlation: -0.279590717582
# Pearson Correlation: -0.546140037064
# Pearson Correlation: -0.0881216339673
# Pearson Correlation: 0.403905418053
# Pearson Correlation: 0.755250505131
# Pearson Correlation: 0.339476408109
# Pearson Correlation: 0.549057229948
# Pearson Correlation: 0.739033938857
# Pearson Correlation: 0.744796824599
# Pearson Correlation: 0.821945371289
# Pearson Correlation: 0.466884246454
# Pearson Correlation: 0.876920310513
# Pearson Correlation: 0.927515534537
# 2013-01-03 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-01-03 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.494477226709
# Pearson Correlation: -0.387391976151
# Pearson Correlation: -0.927721502534
# Pearson Correlation: -0.909803583801
# Pearson Correlation: -0.233228339811
# Pearson Correlation: -0.446151532632
# Pearson Correlation: 0.806202475541
# Pearson Correlation: 0.907783047386
# 2013-01-15 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-01-15 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.696926220586
# Pearson Correlation: 0.442689440196
# Pearson Correlation: -0.496565907528
# Pearson Correlation: -0.717758128217
# Pearson Correlation: 0.91836915185
# 2013-01-23 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-01-23 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: -0.601692961309
# Pearson Correlation: -0.703340810332
# Pearson Correlation: -0.708631151794
# Pearson Correlation: -0.942863822082
# Pearson Correlation: 0.105071788809
# Pearson Correlation: 0.267677939369
# Pearson Correlation: -0.0734603761372
# Pearson Correlation: -0.199311330537
# Pearson Correlation: 0.0510478602377
# Pearson Correlation: 0.353566175356
# Pearson Correlation: 0.693378247595
# Pearson Correlation: 0.952514956078
# 2013-02-08 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-02-08 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.922284099348
# 2013-02-11 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-02-11 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.855718558992
# Pearson Correlation: 0.442512222602
# Pearson Correlation: -0.15909805662
# Pearson Correlation: -0.660823444996
# Pearson Correlation: -0.873349113446
# Pearson Correlation: -0.373572157847
# Pearson Correlation: -0.101445899412
# Pearson Correlation: 0.398375188553
# Pearson Correlation: 0.935757136186
# 2013-02-25 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-02-25 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.488289511759
# Pearson Correlation: 0.236926672758
# Pearson Correlation: -0.134727207432
# Pearson Correlation: -0.800766068617
# Pearson Correlation: -0.966418239347
# Pearson Correlation: -0.612146269391
# Pearson Correlation: -0.523858670059
# Pearson Correlation: 0.128313159843
# Pearson Correlation: 0.856768169064
# Pearson Correlation: 0.37064308425
# Pearson Correlation: 0.694439233109
# Pearson Correlation: 0.848864875018
# Pearson Correlation: 0.583850851016
# Pearson Correlation: -0.382247521161
# Pearson Correlation: -0.986326278298
# Pearson Correlation: -0.982469497378
# Pearson Correlation: -0.916359799195
# Pearson Correlation: -0.69849547277
# Pearson Correlation: -0.483088392126
# Pearson Correlation: -0.769950032764
# Pearson Correlation: -0.692494102481
# Pearson Correlation: 0.534907310429
# Pearson Correlation: 0.973183362731
# 2013-03-28 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-03-28 00:00:00+00:00: Buying 100 GOOG shares.
# Pearson Correlation: 0.726670249705
# Pearson Correlation: 0.143611794748
# Pearson Correlation: -0.465442720063
# Pearson Correlation: -0.395440571443
# Pearson Correlation: 0.888941897899
# Pearson Correlation: 0.799236827344
# Pearson Correlation: 0.759685868182
# Pearson Correlation: 0.457328874099
# Pearson Correlation: 0.780718813282
# Pearson Correlation: 0.863304390263
# Pearson Correlation: 0.724997330538
# Pearson Correlation: 0.623692113603
# Pearson Correlation: 0.744004178512
# Pearson Correlation: 0.894304567757
# Pearson Correlation: 0.204682970752
# Pearson Correlation: 0.203268615806
# Pearson Correlation: 0.408273152978
# [2013-05-28 02:53] INFO: Performance: Simulated 128 trading days out of 128.
# [2013-05-28 02:53] INFO: Performance: first open: 2012-11-01 13:30:00+00:00
# [2013-05-28 02:53] INFO: Performance: last close: 2013-05-07 20:00:00+00:00
# Pearson Correlation: 0.696724629857
# Pearson Correlation: 0.829059086718
# Pearson Correlation: -0.0460241057536
# Pearson Correlation: 0.405794075795
# Pearson Correlation: 0.707738144101
# Pearson Correlation: 0.859529936421
# Pearson Correlation: 0.964752298038
# 2013-05-02 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-05-02 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.838557400323
# Pearson Correlation: 0.985339456603
# 2013-05-06 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-05-06 00:00:00+00:00: Selling 100 GOOG shares.
# Pearson Correlation: 0.987890482366
# 2013-05-07 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-05-07 00:00:00+00:00: Buying 100 GOOG shares.

# %% [markdown]
# ###Graphical analysis of its performance:

# %%
fig = plt.figure(figsize(18,12), dpi=800)
ax1 = plt.subplot(411)
(data.SPX.pct_change() - data.SPX.pct_change()).plot()
(data.GOOG.pct_change() - data.SPX.pct_change()).plot(label='GOOG')
(data.AAPL.pct_change() - data.SPX.pct_change()).plot(label='AAPL')
plt.ylabel("Daily Return")
legend(loc='best')
plt.title("Adj Closing Prices adjusted for S&P movements")
plt.setp(ax2.get_xticklabels(), visible=False)

GOOG_AAPL_COR_V_SP500.buy_orders = np.asarray(GOOG_AAPL_COR_V_SP500.buy_orders)
GOOG_AAPL_COR_V_SP500.sell_orders = np.asarray(GOOG_AAPL_COR_V_SP500.sell_orders)
plt.title("GOOG_AAPL_COR_V_SP500 Results")

ax2 = plt.subplot(412, sharex=ax1)
plt.plot(GOOG_AAPL_COR_V_SP500.buy_orders[:,0], GOOG_AAPL_COR_V_SP500.buy_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR_V_SP500.sell_orders[:,0], GOOG_AAPL_COR_V_SP500.sell_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR_V_SP500.buy_orders[:,0], GOOG_AAPL_COR_V_SP500.buy_orders[:,1], '^', c='m', markersize=10, label='buy')
plt.plot(GOOG_AAPL_COR_V_SP500.sell_orders[:,0], GOOG_AAPL_COR_V_SP500.sell_orders[:,1], 'v', c='k', markersize=10, label='sell')
plt.ylabel('P-Value')
plt.grid(b=True)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.legend()

ax3 = plt.subplot(413, sharex=ax1)
results_GOOG_AAPL_COR_V_SP500.portfolio_value.plot()
plt.setp(ax3.get_xticklabels(), visible=False)
plt.ylabel('Portfolio Value')
plt.legend(loc='best')

ax4 = plt.subplot(414, sharex=ax1)
results_GOOG_AAPL_COR_V_SP500.portfolio_value.pct_change().plot()
plt.ylabel('Portfolio % Change')
plt.legend()

# %%
results_GOOG_AAPL_COR_V_SP500.portfolio_value.describe()
# Out:
# count       128.000000
# mean     129382.282695
# std       21763.335823
# min       99406.087000
# 25%      106066.087000
# 50%      135464.850000
# 75%      149551.835000
# max      159429.835000
# dtype: float64

# %%
results_GOOG_AAPL_COR_V_SP500.portfolio_value.pct_change().describe()
# Out:
# count    127.000000
# mean       0.003798
# std        0.026928
# min       -0.057274
# 25%       -0.009176
# 50%        0.000000
# 75%        0.012873
# max        0.182446
# dtype: float64

# %% [markdown]
# ###The Results:
#
# Our algorithm performed well. The portfolio ending value was approximately 1.6 million, thus our algorithm returned approximately 60% in just 128 days of trading. During that period the returns had a standard deviation of only 0.0269, meaning that it was extremely consistent and non-volatile in generation of alpha. Its greatest single day drawdown was a mere 0.06%, just barely over a 10th of a percent.

# %% [markdown]
# ### Can we do better? Lets optimizing the number of shares we order and using leverage:

# %% [markdown]
# ### need to model slippage

# %%
class GOOG_AAPL_COR_V_SP500_Optimized(TradingAlgorithm): # inherit from TradingAlgorithm
    """
    Google Apple Correlation algorithm adjusted for movements in the S&P500.

    An algorithm designed to exploit the correlation in the movement of Apple's and 
    Google's common stock. 
    """
    def initialize(self):
        self.AUM = 1000000
        self.pricea = 0
        self.priceg = 0
        self.pricespx = 0
        self.trade_size_aapl = 0
        self.trade_size_goog = 0 
        self.window_length = 5 
        self.corr_tolerance = 0.9
        self.max_notional = self.AUM + 0.1
        self.min_notional = self.AUM * (-1) 
        self.pricealag = 0
        self.priceglag = 0
        self.pricespxlag = 0
        self.buy_orders = []
        self.sell_orders = [] 
        self.corr_values_aapl = []
        self.corr_values_goog = []

    def handle_data(self, data):
        self.pricea = data.AAPL.price 
        self.priceg = data.GOOG.price  
        self.pricespx = data.SPX.price
        
        self.trade_size_aapl = round(((self.AUM * .75) / float(self.pricea)))
        self.trade_size_goog = round(((self.AUM * .75) / float(self.priceg)))

        # find percent change and substract movements from SPX
        aapl_mov, goog_mov = self.spx_normalize(data, self.pricea, self.priceg, self.pricespx, self.pricealag, self.priceglag, self.pricespxlag)

        corr, pval = self.correlation(data, self.pricea, self.priceg)
        print 'Pearson Correlation: ' + str(corr)

        #notional = self.portfolio.positions[data.AAPL].amount * pricea
        #notional = notional + self.portfolio.positions[data.GOOG].amount * priceg 

        if goog_mov < 0 and corr > self.corr_tolerance:
            self.order('AAPL',-(self.trade_size_aapl))
            self.sell_orders.append((data.AAPL.datetime, pval))
            print "{dt}: Selling {ts} AAPL shares.".format(dt = data.AAPL.datetime, ts = self.trade_size_aapl)
        elif goog_mov > 0 and corr > self.corr_tolerance:
            self.order('AAPL',(self.trade_size_aapl))
            self.buy_orders.append((data.AAPL.datetime, pval))
            print "{dt}: Buying {ts} AAPL shares.".format(dt = data.AAPL.datetime, ts = self.trade_size_aapl)

        if aapl_mov < 0 and  corr > self.corr_tolerance:
            self.order('GOOG',-(self.trade_size_goog))
            self.sell_orders.append((data.GOOG.datetime, pval))
            print "{dt}: Selling {ts} GOOG shares.".format(dt = data.GOOG.datetime, ts = self.trade_size_goog)
        elif aapl_mov > 0 and corr > self.corr_tolerance:
            self.order('GOOG', self.trade_size_goog)
            self.buy_orders.append((data.GOOG.datetime, pval))  
            print "{dt}: Buying {ts} GOOG shares.".format(dt = data.GOOG.datetime, ts = self.trade_size_goog)

        # lag price variables 
        self.pricealag = data.AAPL.price
        self.priceglag = data.GOOG.price
        self.pricespxlag =  data.SPX.price

    def correlation(self, data, pricea, priceg):
        self.corr_values_aapl.append(pricea)
        self.corr_values_goog.append(priceg)
        corr = pearsonr(self.corr_values_aapl[-self.window_length:], self.corr_values_goog[-self.window_length:]) # [0] only get the correltion
        return corr

    def per_change(self, data, begin, end):
        percent_change = ((end - begin)/begin)
        return percent_change
        
    def spx_normalize(self, data, pricea, priceg, pricespx, pricealag, priceglag, pricespxlag):
        spx_change = self.per_change(data, pricespx, self.pricespxlag)
        aapl_change = (self.per_change(data, pricea, self.pricealag) - spx_change)
        goog_change = (self.per_change(data, priceg, self.priceglag) - spx_change)
        return (aapl_change, goog_change)

# %%
GOOG_AAPL_COR_V_SP500_Optimized = GOOG_AAPL_COR_V_SP500_Optimized()
results_GOOG_AAPL_COR_V_SP500_Optimized = GOOG_AAPL_COR_V_SP500_Optimized.run(data)
# Out:
# Pearson Correlation: nan
# Pearson Correlation: -1.0
# Pearson Correlation: 0.059824040231
# Pearson Correlation: 0.174659180436
# Pearson Correlation: 0.824233785309
# Pearson Correlation: 0.952297709192
# 2012-11-08 00:00:00+00:00: Buying 1403.0 AAPL shares.
# 2012-11-08 00:00:00+00:00: Buying 1150.0 GOOG shares.
# Pearson Correlation: 0.991554650251
# 2012-11-09 00:00:00+00:00: Selling 1379.0 AAPL shares.
# 2012-11-09 00:00:00+00:00: Selling 1131.0 GOOG shares.
# Pearson Correlation: 0.929368022202
# 2012-11-12 00:00:00+00:00: Selling 1390.0 AAPL shares.
# 2012-11-12 00:00:00+00:00: Buying 1126.0 GOOG shares.
# Pearson Correlation: 0.757576476824
# Pearson Correlation: 0.845836369332
# Pearson Correlation: 0.904363385855
# 2012-11-15 00:00:00+00:00: Buying 1435.0 AAPL shares.
# 2012-11-15 00:00:00+00:00: Buying 1159.0 GOOG shares.
# Pearson Correlation: 0.919167495476
# 2012-11-16 00:00:00+00:00: Buying 1430.0 AAPL shares.
# 2012-11-16 00:00:00+00:00: Buying 1159.0 GOOG shares.
# Pearson Correlation: 0.98644535697
# 2012-11-19 00:00:00+00:00: Selling 1333.0 AAPL shares.
# 2012-11-19 00:00:00+00:00: Selling 1122.0 GOOG shares.
# Pearson Correlation: 0.988017374005
# 2012-11-20 00:00:00+00:00: Selling 1345.0 AAPL shares.
# 2012-11-20 00:00:00+00:00: Buying 1119.0 GOOG shares.
# Pearson Correlation: 0.98614541901
# 2012-11-21 00:00:00+00:00: Buying 1343.0 AAPL shares.
# 2012-11-21 00:00:00+00:00: Buying 1126.0 GOOG shares.
# Pearson Correlation: 0.956502301266
# 2012-11-23 00:00:00+00:00: Buying 1320.0 AAPL shares.
# 2012-11-23 00:00:00+00:00: Selling 1123.0 GOOG shares.
# Pearson Correlation: -0.850795924042
# Pearson Correlation: -0.388234458157
# Pearson Correlation: 0.132856328942
# Pearson Correlation: 0.244364901771
# Pearson Correlation: -0.233575324747
# Pearson Correlation: 0.394085687777
# Pearson Correlation: 0.281478815016
# Pearson Correlation: 0.738307236796
# Pearson Correlation: 0.840028399437
# Pearson Correlation: 0.87515944915
# Pearson Correlation: 0.793381038641
# Pearson Correlation: 0.699662917774
# Pearson Correlation: 0.61994502866
# Pearson Correlation: 0.269620004501
# Pearson Correlation: -0.279590717582
# Pearson Correlation: -0.546140037064
# Pearson Correlation: -0.0881216339673
# Pearson Correlation: 0.403905418053
# Pearson Correlation: 0.755250505131
# Pearson Correlation: 0.339476408109
# Pearson Correlation: 0.549057229948
# Pearson Correlation: 0.739033938857
# Pearson Correlation: 0.744796824599
# Pearson Correlation: 0.821945371289
# Pearson Correlation: 0.466884246454
# Pearson Correlation: 0.876920310513
# Pearson Correlation: 0.927515534537
# 2013-01-03 00:00:00+00:00: Selling 1392.0 AAPL shares.
# 2013-01-03 00:00:00+00:00: Buying 1036.0 GOOG shares.
# Pearson Correlation: 0.494477226709
# Pearson Correlation: -0.387391976151
# Pearson Correlation: -0.927721502534
# Pearson Correlation: -0.909803583801
# Pearson Correlation: -0.233228339811
# Pearson Correlation: -0.446151532632
# Pearson Correlation: 0.806202475541
# Pearson Correlation: 0.907783047386
# 2013-01-15 00:00:00+00:00: Selling 1552.0 AAPL shares.
# 2013-01-15 00:00:00+00:00: Buying 1035.0 GOOG shares.
# Pearson Correlation: 0.696926220586
# Pearson Correlation: 0.442689440196
# Pearson Correlation: -0.496565907528
# Pearson Correlation: -0.717758128217
# Pearson Correlation: 0.91836915185
# 2013-01-23 00:00:00+00:00: Selling 1468.0 AAPL shares.
# 2013-01-23 00:00:00+00:00: Selling 1011.0 GOOG shares.
# Pearson Correlation: -0.601692961309
# Pearson Correlation: -0.703340810332
# Pearson Correlation: -0.708631151794
# Pearson Correlation: -0.942863822082
# Pearson Correlation: 0.105071788809
# Pearson Correlation: 0.267677939369
# Pearson Correlation: -0.0734603761372
# Pearson Correlation: -0.199311330537
# Pearson Correlation: 0.0510478602377
# Pearson Correlation: 0.353566175356
# Pearson Correlation: 0.693378247595
# Pearson Correlation: 0.952514956078
# 2013-02-08 00:00:00+00:00: Selling 1579.0 AAPL shares.
# 2013-02-08 00:00:00+00:00: Selling 955.0 GOOG shares.
# Pearson Correlation: 0.922284099348
# 2013-02-11 00:00:00+00:00: Buying 1563.0 AAPL shares.
# 2013-02-11 00:00:00+00:00: Selling 959.0 GOOG shares.
# Pearson Correlation: 0.855718558992
# Pearson Correlation: 0.442512222602
# Pearson Correlation: -0.15909805662
# Pearson Correlation: -0.660823444996
# Pearson Correlation: -0.873349113446
# Pearson Correlation: -0.373572157847
# Pearson Correlation: -0.101445899412
# Pearson Correlation: 0.398375188553
# Pearson Correlation: 0.935757136186
# 2013-02-25 00:00:00+00:00: Selling 1694.0 AAPL shares.
# 2013-02-25 00:00:00+00:00: Selling 948.0 GOOG shares.
# Pearson Correlation: 0.488289511759
# Pearson Correlation: 0.236926672758
# Pearson Correlation: -0.134727207432
# Pearson Correlation: -0.800766068617
# Pearson Correlation: -0.966418239347
# Pearson Correlation: -0.612146269391
# Pearson Correlation: -0.523858670059
# Pearson Correlation: 0.128313159843
# Pearson Correlation: 0.856768169064
# Pearson Correlation: 0.37064308425
# Pearson Correlation: 0.694439233109
# Pearson Correlation: 0.848864875018
# Pearson Correlation: 0.583850851016
# Pearson Correlation: -0.382247521161
# Pearson Correlation: -0.986326278298
# Pearson Correlation: -0.982469497378
# Pearson Correlation: -0.916359799195
# Pearson Correlation: -0.69849547277
# Pearson Correlation: -0.483088392126
# Pearson Correlation: -0.769950032764
# Pearson Correlation: -0.692494102481
# Pearson Correlation: 0.534907310429
# Pearson Correlation: 0.973183362731
# 2013-03-28 00:00:00+00:00: Buying 1694.0 AAPL shares.
# 2013-03-28 00:00:00+00:00: Buying 944.0 GOOG shares.
# Pearson Correlation: 0.726670249705
# Pearson Correlation: 0.143611794748
# Pearson Correlation: -0.465442720063
# Pearson Correlation: -0.395440571443
# Pearson Correlation: 0.888941897899
# Pearson Correlation: 0.799236827344
# Pearson Correlation: 0.759685868182
# Pearson Correlation: 0.457328874099
# Pearson Correlation: 0.780718813282
# Pearson Correlation: 0.863304390263
# Pearson Correlation: 0.724997330538
# Pearson Correlation: 0.623692113603
# Pearson Correlation: 0.744004178512
# Pearson Correlation: 0.894304567757
# Pearson Correlation: 0.204682970752
# Pearson Correlation: 0.203268615806
# [2013-05-28 02:56] INFO: Performance: Simulated 128 trading days out of 128.
# [2013-05-28 02:56] INFO: Performance: first open: 2012-11-01 13:30:00+00:00
# [2013-05-28 02:56] INFO: Performance: last close: 2013-05-07 20:00:00+00:00
# Pearson Correlation: 0.408273152978
# Pearson Correlation: 0.696724629857
# Pearson Correlation: 0.829059086718
# Pearson Correlation: -0.0460241057536
# Pearson Correlation: 0.405794075795
# Pearson Correlation: 0.707738144101
# Pearson Correlation: 0.859529936421
# Pearson Correlation: 0.964752298038
# 2013-05-02 00:00:00+00:00: Selling 1683.0 AAPL shares.
# 2013-05-02 00:00:00+00:00: Selling 904.0 GOOG shares.
# Pearson Correlation: 0.838557400323
# Pearson Correlation: 0.985339456603
# 2013-05-06 00:00:00+00:00: Selling 1628.0 AAPL shares.
# 2013-05-06 00:00:00+00:00: Selling 871.0 GOOG shares.
# Pearson Correlation: 0.987890482366
# 2013-05-07 00:00:00+00:00: Buying 1635.0 AAPL shares.
# 2013-05-07 00:00:00+00:00: Buying 875.0 GOOG shares.

# %%
fig = plt.figure(figsize(18,12), dpi=800)
ax1 = plt.subplot(411)
(data.SPX.pct_change() - data.SPX.pct_change()).plot()
(data.GOOG.pct_change() - data.SPX.pct_change()).plot(label='GOOG')
(data.AAPL.pct_change() - data.SPX.pct_change()).plot(label='AAPL')
plt.ylabel("Daily Return")
legend(loc='best')
plt.title("Adj Closing Prices adjusted for S&P movements")
plt.setp(ax2.get_xticklabels(), visible=False)

GOOG_AAPL_COR_V_SP500_Optimized.buy_orders = np.asarray(GOOG_AAPL_COR_V_SP500_Optimized.buy_orders)
GOOG_AAPL_COR_V_SP500_Optimized.sell_orders = np.asarray(GOOG_AAPL_COR_V_SP500_Optimized.sell_orders)
plt.title("GOOG_AAPL_COR_V_SP500_Optimized Results")

ax2 = plt.subplot(412, sharex=ax1)
plt.plot(GOOG_AAPL_COR_V_SP500_Optimized.buy_orders[:,0], GOOG_AAPL_COR_V_SP500_Optimized.buy_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR_V_SP500_Optimized.sell_orders[:,0], GOOG_AAPL_COR_V_SP500_Optimized.sell_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR_V_SP500_Optimized.buy_orders[:,0], GOOG_AAPL_COR_V_SP500_Optimized.buy_orders[:,1], '^', c='m', markersize=10, label='buy')
plt.plot(GOOG_AAPL_COR_V_SP500_Optimized.sell_orders[:,0], GOOG_AAPL_COR_V_SP500_Optimized.sell_orders[:,1], 'v', c='k', markersize=10, label='sell')
plt.ylabel('P-Value')
plt.grid(b=True)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.legend()

ax3 = plt.subplot(413, sharex=ax1)
results_GOOG_AAPL_COR_V_SP500_Optimized.portfolio_value.plot()
plt.setp(ax3.get_xticklabels(), visible=False)
plt.ylabel('Portfolio Value')
plt.legend(loc='best')

ax4 = plt.subplot(414, sharex=ax1)
results_GOOG_AAPL_COR_V_SP500_Optimized.portfolio_value.pct_change().plot()
plt.ylabel('Portfolio % Change')
plt.legend()

# %%
results_GOOG_AAPL_COR_V_SP500_Optimized.portfolio_value.describe()
# Out:
# count       128.000000
# mean     152697.094762
# std       49227.484072
# min       84144.484375
# 25%      100794.484375
# 50%      161466.978806
# 75%      189512.353432
# max      289641.990618
# dtype: float64

# %%
results_GOOG_AAPL_COR_V_SP500_Optimized.portfolio_value.pct_change().describe()
# Out:
# count    127.000000
# mean       0.011450
# std        0.085456
# min       -0.201071
# 25%       -0.025435
# 50%       -0.000834
# 75%        0.033318
# max        0.544538
# dtype: float64

# %% [markdown]
# ###The Results:

# %% [markdown]
# ###Aggregated performance between models:

# %%
fig = plt.figure(figsize(20,8), dpi=800)
ax1 = plt.subplot(211)
results_GOOG_AAPL_COR.portfolio_value.plot(label='GOOG_AAPL_COR')
results_GOOG_AAPL_COR_V_SP500.portfolio_value.plot(label='GOOG_AAPL_COR_V_SP500')
results_GOOG_AAPL_COR_V_SP500_Optimized.portfolio_value.plot(label='GOOG_AAPL_COR_V_SP500_Optimized')
plt.setp(ax3.get_xticklabels(), visible=False)
plt.ylabel('Portfolio Value')
plt.legend(loc='best')
plt.title('Aggreated Performance')

ax1 = plt.subplot(212, sharex=ax1)
results_GOOG_AAPL_COR.portfolio_value.pct_change().plot(label='GOOG_AAPL_COR')
results_GOOG_AAPL_COR_V_SP500.portfolio_value.pct_change().plot(label='GOOG_AAPL_COR_V_SP500')
results_GOOG_AAPL_COR_V_SP500_Optimized.portfolio_value.pct_change().plot(label='GOOG_AAPL_COR_V_SP500_Optimized')
plt.ylabel('Portfolio % Change')
plt.legend(loc='best')

# %% [markdown]
# ###Lets re-run our algorithms on minute bar data:

# %%
GOOG_AAPL_COR_V_SP500_Optimized = GOOG_AAPL_COR_V_SP500_Optimized()
results_GOOG_AAPL_COR_V_SP500_Optimized = GOOG_AAPL_COR_V_SP500_Optimized.run()

# %% [markdown]
# ##Version Control

# %%
# !git add "GOOG V. AAPL Correlation Arb".ipynb

# %%
# !git commit
# Out:
# [master 89ebe5d] updated ploting
#  1 file changed, 52 insertions(+), 9 deletions(-)
