# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
plt.figsize(14,6)

from zipline.algorithm import TradingAlgorithm
from zipline.transforms import MovingAverage, batch_transform
from zipline.utils.factory import load_from_yahoo

# %%
#data = load_from_yahoo(stocks=['AAPL', 'GOOG'],start=datetime.datetime(2012,11,1), end=datetime.datetime(2013,5,8)); data.save('goog_aapl_tests.dat')
data = pd.load('goog_aapl_tests.dat')

# %%
cont = []
cont[:] = []
for i in range(0, data.AAPL.size+1):
    cont.append(pearsonr(data.AAPL.ix[(i-5):i], (data.GOOG.ix[(i-5):i]))[0])
print cont
# Out:
# [nan, nan, nan, nan, nan, 0.82423378530858804, 0.95229770919167034, 0.99155465025083822, 0.92936802220249815, 0.75757647682366547, 0.84583636933160089, 0.90436338585457976, 0.9191674954757727, 0.98644535696980762, 0.98801737400467349, 0.98614541900960007, 0.95650230126613145, -0.85079592404219251, -0.38823445815696739, 0.13285632894234831, 0.24436490177133713, -0.23357532474663709, 0.39408568777747061, 0.28147881501625127, 0.73830723679559151, 0.84002839943741692, 0.87515944915033494, 0.79338103864063469, 0.69966291777419387, 0.61994502866001699, 0.26962000450065748, -0.27959071758162402, -0.5461400370637276, -0.088121633967325266, 0.40390541805307251, 0.75525050513144432, 0.33947640810916474, 0.54905722994810113, 0.73903393885662827, 0.74479682459947738, 0.8219453712890511, 0.46688424645399079, 0.87692031051299246, 0.92751553453715119, 0.49447722670921102, -0.38739197615137949, -0.92772150253446217, -0.90980358380127757, -0.23322833981132293, -0.44615153263153007, 0.80620247554113533, 0.90778304738570958, 0.69692622058558107, 0.44268944019593481, -0.49656590752772212, -0.71775812821657348, 0.91836915185024004, -0.60169296130944339, -0.70334081033182339, -0.70863115179381786, -0.94286382208227548, 0.10507178880933711, 0.26767793936933743, -0.073460376137172212, -0.19931133053709682, 0.051047860237657602, 0.35356617535642215, 0.69337824759549815, 0.95251495607796532, 0.92228409934783007, 0.85571855899197202, 0.44251222260182804, -0.15909805662044499, -0.66082344499648482, -0.873349113445679, -0.37357215784744596, -0.10144589941178088, 0.39837518855348353, 0.93575713618612755, 0.48828951175869206, 0.23692667275811538, -0.13472720743241642, -0.80076606861718835, -0.96641823934664461, -0.61214626939094097, -0.52385867005927433, 0.12831315984314065, 0.85676816906406417, 0.37064308425006287, 0.69443923310941125, 0.84886487501779162, 0.58385085101591605, -0.38224752116134392, -0.98632627829837283, -0.98246949737755263, -0.91635979919476507, -0.6984954727703615, -0.48308839212648269, -0.76995003276357121, -0.69249410248069421, 0.53490731042871575, 0.97318336273094941, 0.72667024970526084, 0.14361179474837996, -0.46544272006328929, -0.39544057144252703, 0.88894189789918177, 0.79923682734419788, 0.75968586818167172, 0.45732887409933748, 0.78071881328218828, 0.8633043902625398, 0.72499733053762405, 0.6236921136025293, 0.74400417851245182, 0.89430456775725731, 0.20468297075217221, 0.20326861580641858, 0.40827315297787908, 0.69672462985666983, 0.82905908671831841, -0.046024105753595654, 0.40579407579518234, 0.70773814410142033, 0.85952993642103526, 0.96475229803819496, 0.83855740032313797, 0.98533945660273781, 0.98789048236649957]

# %%
cont = []
cont[:] = []
for i in range(0, data.AAPL.size+1):
    cont.append(data.AAPL.ix[(i-5):i].corr(data.GOOG.ix[(i-5):i]))
print cont
# Out:
# [nan, nan, nan, nan, nan, 0.82423378530858804, 0.95229770919167023, 0.99155465025083811, 0.92936802220249803, 0.75757647682366547, 0.845836369331601, 0.90436338585457976, 0.91916749547577292, 0.98644535696980784, 0.9880173740046736, 0.98614541900960007, 0.95650230126613156, -0.85079592404219262, -0.38823445815696733, 0.13285632894234831, 0.2443649017713371, -0.23357532474663709, 0.39408568777747061, 0.28147881501625127, 0.73830723679559151, 0.84002839943741681, 0.87515944915033483, 0.79338103864063469, 0.69966291777419387, 0.61994502866001711, 0.26962000450065748, -0.27959071758162402, -0.5461400370637276, -0.088121633967325266, 0.40390541805307245, 0.75525050513144432, 0.3394764081091648, 0.54905722994810124, 0.73903393885662827, 0.74479682459947738, 0.8219453712890511, 0.46688424645399079, 0.87692031051299246, 0.92751553453715108, 0.49447722670921102, -0.38739197615137949, -0.92772150253446206, -0.90980358380127746, -0.23322833981132293, -0.44615153263153012, 0.80620247554113522, 0.90778304738570958, 0.69692622058558107, 0.44268944019593481, -0.49656590752772206, -0.71775812821657348, 0.91836915185023993, -0.60169296130944339, -0.7033408103318235, -0.70863115179381786, -0.94286382208227548, 0.10507178880933712, 0.26767793936933743, -0.073460376137172198, -0.19931133053709682, 0.051047860237657602, 0.35356617535642215, 0.69337824759549804, 0.95251495607796544, 0.92228409934783007, 0.85571855899197202, 0.44251222260182799, -0.15909805662044499, -0.66082344499648482, -0.87334911344567889, -0.37357215784744591, -0.10144589941178088, 0.39837518855348353, 0.93575713618612755, 0.48828951175869206, 0.23692667275811541, -0.13472720743241645, -0.80076606861718846, -0.9664182393466445, -0.61214626939094086, -0.52385867005927444, 0.12831315984314068, 0.85676816906406406, 0.37064308425006287, 0.69443923310941125, 0.84886487501779162, 0.58385085101591605, -0.38224752116134397, -0.98632627829837283, -0.98246949737755274, -0.91635979919476507, -0.6984954727703615, -0.48308839212648264, -0.7699500327635711, -0.69249410248069432, 0.53490731042871575, 0.97318336273094952, 0.72667024970526084, 0.14361179474837996, -0.46544272006328935, -0.39544057144252698, 0.88894189789918165, 0.79923682734419799, 0.75968586818167183, 0.45732887409933753, 0.78071881328218817, 0.8633043902625398, 0.72499733053762405, 0.6236921136025293, 0.74400417851245182, 0.89430456775725742, 0.20468297075217223, 0.20326861580641856, 0.40827315297787908, 0.69672462985666983, 0.82905908671831829, -0.046024105753595661, 0.40579407579518234, 0.70773814410142044, 0.85952993642103526, 0.96475229803819473, 0.83855740032313786, 0.98533945660273792, 0.98789048236649946]

# %%
cont = pd.Series(cont)

# %%
len(cont[cont > 0.8])
# Out:
# 35

# %%
fig = plt.figure(figsize(20,8))

ax1 = fig.add_subplot(211)
data.SPX.plot(label='S&P Benchmark')
data.GOOG.plot()
data.AAPL.plot()
legend(loc='best')
plt.setp(ax1.get_xticklabels(), visible=False)

ax2 = fig.add_subplot(212, sharex=ax1)
(data.SPX.pct_change() - data.SPX.pct_change()).plot(label='S&P Benchmark, flatlined')
(data.GOOG.pct_change() - data.SPX.pct_change()).plot(label='GOOG adj for var in S&P')
(data.AAPL.pct_change() - data.SPX.pct_change()).plot(label='AAPL adj for var in S&P')

legend(loc='best')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.figsize(14,8)

from zipline.algorithm import TradingAlgorithm
from zipline.transforms import MovingAverage, batch_transform
from zipline.utils.factory import load_from_yahoo

class GOOG_AAPL_COR(TradingAlgorithm): # inherit from TradingAlgorithm
	"""
	Google Apple Correlation algorithm.

	An algorithm designed to exploit the correlation in the movement of Apple's and 
	Google's common stock. 
	"""
	def initialize(self):
		AUM = 1000000
		self.window_length = 5 
		self.corr_tolerance = 0.9
		self.max_notional = AUM + 0.1
		self.min_notional = AUM * (-1) 
		self.pricealag = 0
		self.priceglag = 0
		self.buy_orders = []
		self.sell_orders = [] 
		self.corr_values_aapl = []
		self.corr_values_goog = []

	def handle_data(self, data):

		pricea = data.AAPL.price
		priceg = data.GOOG.price   
        
		corr, pval = self.correlation(data, pricea, priceg)
		print corr

		#notional = self.portfolio.positions[data.AAPL].amount * pricea
		#notional = notional + self.portfolio.positions[data.GOOG].amount * priceg 
        
        #substract movements from SPX

		# need to include and optimization for # of shares
		if priceg < self.priceglag and corr > self.corr_tolerance:
			self.order('AAPL',-100)
			self.sell_orders.append((data.AAPL.datetime, pval))
			print "{dt}: Selling 100 AAPL shares.".format(dt = data.AAPL.datetime)
		elif priceg > self.priceglag and corr > self.corr_tolerance:
			self.order('AAPL',100)
			self.buy_orders.append((data.AAPL.datetime, pval))
			print "{dt}: Buying 100 AAPL shares.".format(dt = data.AAPL.datetime)

		if pricea < self.pricealag and  corr > self.corr_tolerance:
			self.order('GOOG',-100)
			self.sell_orders.append((data.GOOG.datetime, pval))
			print "{dt}: Selling 100 GOOG shares.".format(dt = data.GOOG.datetime)
		elif pricea > self.pricealag and corr > self.corr_tolerance:
			self.order('GOOG',100)
			self.buy_orders.append((data.GOOG.datetime, pval))  
			print "{dt}: Buying 100 GOOG shares.".format(dt = data.GOOG.datetime)

		# lag price variables 
		self.pricealag = data.AAPL.price
		self.priceglag = data.GOOG.price

	def correlation(self, data, pricea, priceg):
		self.corr_values_aapl.append(pricea)
		self.corr_values_goog.append(priceg)
		corr = pearsonr(self.corr_values_aapl[-self.window_length:], self.corr_values_goog[-self.window_length:]) # [0] only get the correltion
		return corr

# %%
GOOG_AAPL_COR = GOOG_AAPL_COR()
results_GOOG_AAPL_COR = GOOG_AAPL_COR.run(data)
# Out:
# nan
# -1.0
# 0.059824040231
# 0.174659180436
# 0.824233785309
# 0.952297709192
# 2012-11-08 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-08 00:00:00+00:00: Selling 100 GOOG shares.
# 0.991554650251
# 2012-11-09 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-09 00:00:00+00:00: Buying 100 GOOG shares.
# 0.929368022202
# 2012-11-12 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-12 00:00:00+00:00: Selling 100 GOOG shares.
# 0.757576476824
# 0.845836369332
# 0.904363385855
# 2012-11-15 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-15 00:00:00+00:00: Selling 100 GOOG shares.
# 0.919167495476
# 2012-11-16 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-16 00:00:00+00:00: Buying 100 GOOG shares.
# 0.98644535697
# 2012-11-19 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-19 00:00:00+00:00: Buying 100 GOOG shares.
# 0.988017374005
# 2012-11-20 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-20 00:00:00+00:00: Selling 100 GOOG shares.
# 0.98614541901
# 2012-11-21 00:00:00+00:00: Selling 100 AAPL shares.
# 2012-11-21 00:00:00+00:00: Buying 100 GOOG shares.
# 0.956502301266
# 2012-11-23 00:00:00+00:00: Buying 100 AAPL shares.
# 2012-11-23 00:00:00+00:00: Buying 100 GOOG shares.
# -0.850795924042
# -0.388234458157
# 0.132856328942
# 0.244364901771
# -0.233575324747
# 0.394085687777
# 0.281478815016
# 0.738307236796
# 0.840028399437
# 0.87515944915
# 0.793381038641
# 0.699662917774
# 0.61994502866
# 0.269620004501
# -0.279590717582
# -0.546140037064
# -0.0881216339673
# 0.403905418053
# 0.755250505131
# 0.339476408109
# 0.549057229948
# 0.739033938857
# 0.744796824599
# 0.821945371289
# 0.466884246454
# 0.876920310513
# 0.927515534537
# 2013-01-03 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-01-03 00:00:00+00:00: Selling 100 GOOG shares.
# 0.494477226709
# -0.387391976151
# -0.927721502534
# -0.909803583801
# -0.233228339811
# -0.446151532632
# 0.806202475541
# 0.907783047386
# 2013-01-15 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-01-15 00:00:00+00:00: Selling 100 GOOG shares.
# 0.696926220586
# 0.442689440196
# -0.496565907528
# -0.717758128217
# 0.91836915185
# 2013-01-23 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-01-23 00:00:00+00:00: Buying 100 GOOG shares.
# -0.601692961309
# -0.703340810332
# -0.708631151794
# -0.942863822082
# 0.105071788809
# 0.267677939369
# -0.0734603761372
# -0.199311330537
# 0.0510478602377
# 0.353566175356
# 0.693378247595
# 0.952514956078
# 2013-02-08 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-02-08 00:00:00+00:00: Buying 100 GOOG shares.
# 0.922284099348
# 2013-02-11 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-02-11 00:00:00+00:00: Buying 100 GOOG shares.
# 0.855718558992
# 0.442512222602
# -0.15909805662
# -0.660823444996
# -0.873349113446
# -0.373572157847
# -0.101445899412
# 0.398375188553
# 0.935757136186
# 2013-02-25 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-02-25 00:00:00+00:00: Selling 100 GOOG shares.
# 0.488289511759
# 0.236926672758
# -0.134727207432
# -0.800766068617
# -0.966418239347
# -0.612146269391
# -0.523858670059
# 0.128313159843
# 0.856768169064
# 0.37064308425
# 0.694439233109
# 0.848864875018
# 0.583850851016
# -0.382247521161
# -0.986326278298
# -0.982469497378
# -0.916359799195
# -0.69849547277
# -0.483088392126
# -0.769950032764
# -0.692494102481
# 0.534907310429
# 0.973183362731
# 2013-03-28 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-03-28 00:00:00+00:00: Selling 100 GOOG shares.
# 0.726670249705
# 0.143611794748
# -0.465442720063
# -0.395440571443
# 0.888941897899
# 0.799236827344
# 0.759685868182
# 0.457328874099
# 0.780718813282
# 0.863304390263
# 0.724997330538
# 0.623692113603
# 0.744004178512
# 0.894304567757
# 0.204682970752
# [2013-05-23 14:16] INFO: Performance: Simulated 128 trading days out of 128.
# [2013-05-23 14:16] INFO: Performance: first open: 2012-11-01 13:30:00+00:00
# [2013-05-23 14:16] INFO: Performance: last close: 2013-05-07 20:00:00+00:00
# 0.203268615806
# 0.408273152978
# 0.696724629857
# 0.829059086718
# -0.0460241057536
# 0.405794075795
# 0.707738144101
# 0.859529936421
# 0.964752298038
# 2013-05-02 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-05-02 00:00:00+00:00: Buying 100 GOOG shares.
# 0.838557400323
# 0.985339456603
# 2013-05-06 00:00:00+00:00: Buying 100 AAPL shares.
# 2013-05-06 00:00:00+00:00: Buying 100 GOOG shares.
# 0.987890482366
# 2013-05-07 00:00:00+00:00: Selling 100 AAPL shares.
# 2013-05-07 00:00:00+00:00: Selling 100 GOOG shares.

# %%
ax1 = plt.subplot(311)
data[['GOOG', 'AAPL']].plot(ax=ax1)
plt.ylabel('price')
plt.setp(ax1.get_xticklabels(), visible=False)

GOOG_AAPL_COR.buy_orders = np.asarray(GOOG_AAPL_COR.buy_orders)
GOOG_AAPL_COR.sell_orders = np.asarray(GOOG_AAPL_COR.sell_orders)

ax2 = plt.subplot(312, sharex=ax1)
plt.plot(GOOG_AAPL_COR.buy_orders[:,0], GOOG_AAPL_COR.buy_orders[:,1], color = 'g')
plt.plot(GOOG_AAPL_COR.sell_orders[:,0], GOOG_AAPL_COR.sell_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR.buy_orders[:,0], GOOG_AAPL_COR.buy_orders[:,1], '^', c='g', markersize=10, label='buy')
plt.plot(GOOG_AAPL_COR.sell_orders[:,0], GOOG_AAPL_COR.sell_orders[:,1], 'v', c='r', markersize=10, label='sell')
plt.ylabel('pval of correlation')
plt.setp(ax2.get_xticklabels(), visible=False)
plt.legend()

ax3 = plt.subplot(313, sharex=ax1)
results_GOOG_AAPL_COR.portfolio_value.plot()
plt.ylabel('Nominal Portfolio Value')
plt.legend()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.figsize(14,8)

from zipline.algorithm import TradingAlgorithm
from zipline.transforms import MovingAverage, batch_transform
from zipline.utils.factory import load_from_yahoo

class GOOG_AAPL_COR_V_SP500(TradingAlgorithm): # inherit from TradingAlgorithm
	"""
	Google Apple Correlation algorithm adjusted for movements in the S&P500.

	An algorithm designed to exploit the correlation in the movement of Apple's and 
	Google's common stock. 
	"""
	def initialize(self):
		AUM = 1000000
		self.window_length = 5 
		self.corr_tolerance = 0.9
		self.max_notional = AUM + 0.1
		self.min_notional = AUM * (-1) 
		self.pricealag = 0
		self.priceglag = 0
		self.pricespxlag = 0
        self.buy_orders = []
		self.sell_orders = [] 
		self.corr_values_aapl = []
		self.corr_values_goog = []

	def handle_data(self, data):

        pricea = data.AAPL.price 
		priceg = data.GOOG.price  
        pricespx = data.SPX.price
        
        # find percent change and substract movements from SPX
        aapl_mov, goog_mov = spx_normalize(data, pricea, priceg, pricespx, pricealag, priceglag, pricespxlag)

		corr, pval = self.correlation(data, pricea, priceg)
		print corr

		#notional = self.portfolio.positions[data.AAPL].amount * pricea
		#notional = notional + self.portfolio.positions[data.GOOG].amount * priceg 

		# need to include and optimization for # of shares
		if goog_mov < 0 and corr > self.corr_tolerance:
			self.order('AAPL',-100)
			self.sell_orders.append((data.AAPL.datetime, pval))
			print "{dt}: Selling 100 AAPL shares.".format(dt = data.AAPL.datetime)
		elif goog_mov > 0 and corr > self.corr_tolerance:
			self.order('AAPL',100)
			self.buy_orders.append((data.AAPL.datetime, pval))
			print "{dt}: Buying 100 AAPL shares.".format(dt = data.AAPL.datetime)

		if aapl_mov < 0 and  corr > self.corr_tolerance:
			self.order('GOOG',-100)
			self.sell_orders.append((data.GOOG.datetime, pval))
			print "{dt}: Selling 100 GOOG shares.".format(dt = data.GOOG.datetime)
		elif aapl_mov > 0 and corr > self.corr_tolerance:
			self.order('GOOG',100)
			self.buy_orders.append((data.GOOG.datetime, pval))  
			print "{dt}: Buying 100 GOOG shares.".format(dt = data.GOOG.datetime)

		# lag price variables 
		self.pricealag = data.AAPL.price
		self.priceglag = data.GOOG.price
        self.pricespxlag =  data.SPX.price
        
	def correlation(self, data, pricea, priceg):
		self.corr_values_aapl.append(pricea)
		self.corr_values_goog.append(priceg)
		corr = pearsonr(self.corr_values_aapl[-self.window_length:], self.corr_values_goog[-self.window_length:]) # [0] only get the correltion
		return corr
   
    def per_change(self, data, begin, end):
        percent_change = ((data.end.price - data.begin.price)/data.begin.price)
        return percent_change
    
    def spx_normalize(self, data, pricea, priceg, pricespx, pricealag, priceglag, pricespxlag):
        spx_change = per_change(data,pricespx, self.pricespxlag)
        aapl_change = (per_change(data,pricea, self.pricealag) - spx_change)
        goog_change = (per_change(data,priceg, self.priceglag) - spx_change)
        return (aapl_change, goog_change)
# Out:
#   File "<ipython-input-42-1ebf14b8ea72>", line 27
#     self.sell_orders = []
#     ^
# IndentationError: unexpected indent

# %%
GOOG_AAPL_COR_V_SP500 = GOOG_AAPL_COR_V_SP500()
results_GOOG_AAPL_COR_V_SP500 = GOOG_AAPL_COR_V_SP500.run(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-6dd55f89b9b3> in <module>()
#       1 GOOG_AAPL_COR_V_SP500 = GOOG_AAPL_COR_V_SP500()
# ----> 2 results_GOOG_AAPL_COR_V_SP500 = GOOG_AAPL_COR_V_SP500.run(data)
#
# C:\Python27\lib\site-packages\zipline\algorithm.pyc in run(self, source, sim_params)
#     233         # loop through simulated_trading, each iteration returns a
#     234         # perf dictionary
# --> 235         perfs = list(self.gen)
#     236
#     237         # convert perf dict to pandas dataframe
#
# C:\Python27\lib\site-packages\zipline\gens\tradesimulation.pyc in simulate(self, stream_in)
#     132         # day.  It will also yield a risk report at the end of the
#     133         # simulation.
# --> 134         for message in performance_messages:
#     135             yield message
#     136
#
# C:\Python27\lib\site-packages\zipline\gens\tradesimulation.pyc in transform(self, stream_in)
#     273                     # Send the current state of the universe
#     274                     # to the user's algo.
# --> 275                     self.simulate_snapshot(date)
#     276
#     277             perf_messages, risk_message = \
#
# C:\Python27\lib\site-packages\zipline\gens\tradesimulation.pyc in simulate_snapshot(self, date)
#     312         self.snapshot_dt = date
#     313         self.algo.set_datetime(self.snapshot_dt)
# --> 314         self.algo.handle_data(self.universe)
#     315
#     316         # Update the simulation time.
#
# <ipython-input-29-9cf446c93454> in handle_data(self, data)
#      30         def handle_data(self, data):
#      31
# ---> 32                 pricea = (data.AAPL.pct_change() - data.SPX.pct_change())
#      33                 priceg = (data.GOOG.pct_change() - data.SPX.pct_change())
#      34
#
# AttributeError: 'SIDData' object has no attribute 'pct_change'

# %%
ax1 = plt.subplot(311)
data[['GOOG', 'AAPL']].plot(ax=ax1)
plt.ylabel('price')
plt.setp(ax1.get_xticklabels(), visible=False)

GOOG_AAPL_COR.buy_orders = np.asarray(GOOG_AAPL_COR.buy_orders)
GOOG_AAPL_COR.sell_orders = np.asarray(GOOG_AAPL_COR.sell_orders)

ax2 = plt.subplot(312, sharex=ax1)
plt.plot(GOOG_AAPL_COR.buy_orders[:,1], GOOG_AAPL_COR.buy_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR.sell_orders[:,1], GOOG_AAPL_COR.sell_orders[:,1], color = 'r')
plt.plot(GOOG_AAPL_COR.buy_orders[:,0], GOOG_AAPL_COR.buy_orders[:,1], '^', c='m', markersize=10, label='buy')
plt.plot(GOOG_AAPL_COR.sell_orders[:,0], GOOG_AAPL_COR.sell_orders[:,1], 'v', c='k', markersize=10, label='sell')
plt.ylabel('zscore of spread')
plt.setp(ax2.get_xticklabels(), visible=False)
plt.legend()

ax3 = plt.subplot(313, sharex=ax1)
results_GOOG_AAPL_COR.portfolio_value.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-315334503c6f> in <module>()
#       4 plt.setp(ax1.get_xticklabels(), visible=False)
#       5
# ----> 6 GOOG_AAPL_COR.buy_orders = np.asarray(GOOG_AAPL_COR.buy_orders)
#       7 GOOG_AAPL_COR.sell_orders = np.asarray(GOOG_AAPL_COR.sell_orders)
#       8
#
# NameError: name 'GOOG_AAPL_COR' is not defined

# %%
import statsmodels.api as sm

WINDOW_LENGTH = 100

@batch_transform
def ols_transform(data): # receives constantly updated dataframe
    """Computes regression coefficient (slope and intercept)
    via Ordinary Least Squares between two SIDs.
    """
    p0 = data.price['PEP']
    p1 = sm.add_constant(data.price['KO'], prepend=False)
    slope, intercept = sm.OLS(p0, p1).fit().params

    return slope, intercept

class Pairtrade(TradingAlgorithm):
    def initialize(self):
        self.ols_transform = ols_transform(refresh_period=WINDOW_LENGTH, days=WINDOW_LENGTH)
        
        self.spreads = []
        self.zscores = []
        self.invested = False
        self.buy_orders = []
        self.sell_orders = []

    def handle_data(self, data):
        ######################################################
        # 1. Compute regression coefficients between PEP and KO
        params = self.ols_transform.handle_data(data)
        if params is None: # Still in the warm-up period?
            return
        slope, intercept = params
        
        ######################################################
        # 2. Compute zscore of spread (remove mean and divide by std)
        zscore = self.compute_zscore(data, slope, intercept)
        self.zscores.append(zscore)
        
        ######################################################
        # 3. Place orders
        self.place_orders(data, zscore)

        
    def compute_zscore(self, data, slope, intercept):
        """1. Compute the spread given slope and intercept.
           2. zscore the spread.
        """
        spread = (data['PEP'].price - (slope * data['KO'].price + intercept))
        self.spreads.append(spread)
        zscore = (spread - np.mean(self.spreads[-WINDOW_LENGTH:])) / np.std(self.spreads[-WINDOW_LENGTH:])
        return zscore

    
    def place_orders(self, data, zscore):
        """Buy spread if zscore is > 2, sell if zscore < .5.
        """
        if zscore >= 2.0 and not self.invested:
            self.order('PEP', int(100 / data['PEP'].price))
            self.order('KO', -int(100 / data['KO'].price))
            self.invested = True
            self.buy_orders.append(data['PEP'].datetime)
        elif zscore <= -2.0 and not self.invested:
            self.order('KO', -int(100 / data['KO'].price))
            self.order('PEP', int(100 / data['PEP'].price))
            self.invested = True
            self.buy_orders.append(data['PEP'].datetime)
        elif abs(zscore) < .5 and self.invested:
            self.sell_spread()
            self.invested = False
            self.sell_orders.append(data['PEP'].datetime)
        
    def sell_spread(self):
        """
        decrease exposure, regardless of position long/short.
        buy for a short position, sell for a long.
        """
        ko_amount = self.portfolio.positions['KO'].amount
        self.order('KO', -1 * ko_amount)
        pep_amount = self.portfolio.positions['PEP'].amount
        self.order('KO', -1 * pep_amount)

# %%
pairtrade = Pairtrade()
stats = pairtrade.run(data)

# %%
data['zscores'] = np.nan
data.zscores[70:] = pairtrade.zscores

ax1 = plt.subplot(311)
data[['PEP', 'KO']].plot(ax=ax1)
plt.ylabel('price')
plt.setp(ax1.get_xticklabels(), visible=False)

ax2 = plt.subplot(312, sharex=ax1)
data.zscores.plot(ax=ax2, color='r')
plt.plot(pairtrade.buy_orders, data.zscores.ix[pairtrade.buy_orders], '^', c='m', markersize=10, label='buy')
plt.plot(pairtrade.sell_orders, data.zscores.ix[pairtrade.sell_orders], 'v', c='k', markersize=10, label='sell')
plt.ylabel('zscore of spread')
plt.setp(ax2.get_xticklabels(), visible=False)
plt.legend()

ax3 = plt.subplot(313, sharex=ax1)
stats.portfolio_value.plot()

# %% [markdown]
# ##Version Control

# %%
# !git add "GOOG V. AAPL Correlation Arb".ipynb

# %%
# !git commit
# Out:
# Aborting commit due to empty commit message.
